# %% [markdown]
# <a href="https://colab.research.google.com/github/nandinikodhanda60-alt/python-dailly-notes/blob/main/nandinikodhanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
length=float(input("enter the length of the rectangle:"))
width=float(input("enter the width of the rectangle:"))
area=length*width
print("the area of rectangle is:",area)
# Out:
# enter the length of the rectangle:14
# enter the width of the rectangle:56
# the area of rectangle is: 784.0

# %%
write a program of parameter square?
a=float(input("enter the side of a square"))
area=4*a
print("the side of a square is:",a)
# Out:
# Object `square` not found.
# enter the side of a square78
# the side of a square is: 78.0

# %%
write a program to find a area of triangle?

# %%
base=float(input("enter the base"))
height=float(input("enter the height"))
triangle=0.5*base*height
print("the area of triangle is:",triangle)
# Out:
# enter the base56
# enter the height76
# the area of triangle is: 2128.0

# %%
write a program to find circumference of a circle

# %%
radius=float(input("enter the radius of a circle"))
circumference =2*3.14*radius
print("the circumference of a circle is:",circumference)
# Out:
# enter the radius of a circle45
# the circumference of a circle is: 282.6

# %%
write a program to find simple intrests?

# %%
p=float(input("enter a price"))
r=float(input("enter a intrests"))
t=float(input("enter a time"))
simple_intrests=p*r*t/100
print("simple intrests is:",simple_intrests)
# Out:
# enter a price500
# enter a intrests12
# enter a time5
# simple intrests is: 300.0
